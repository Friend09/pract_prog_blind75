# %% [markdown]
# # BACKTRACKING

# %% [markdown]
# ## find_all_permutations.py

# %% [markdown]
# ## find_all_subsets.py

# %% [markdown]
# ## n_queens.py

# %% [markdown]
# ## combinations_of_sum_k.py

# %% [markdown]
# ## phone_keypad_combinations.py

# %% [markdown]
# # MODULE PRACTICE CODE
